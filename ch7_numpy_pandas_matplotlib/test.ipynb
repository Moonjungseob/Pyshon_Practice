# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.randn(10)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [-0.88320355 -1.038493   -0.396124   -0.11344402 -0.90641512  0.88971402
#  -0.10905482  0.58973259  0.08453058  1.0858191 ]

# %%
seri = pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0   -0.883204
# 1   -1.038493
# 2   -0.396124
# 3   -0.113444
# 4   -0.906415
# 5    0.889714
# 6   -0.109055
# 7    0.589733
# 8    0.084531
# 9    1.085819
# dtype: float64

# %%
seri.plot()
# Out:
# <Axes: >
