# %%
# 주의사항, 문자열 안에 특수문자 부분 체크 잘하기.
# create table newsTable (
# id int not null auto_increment,
# title varchar(200),
# publisher varchar(200),
# newsDate varchar(10),
# newsTime varchar(10),
# newsDetail varchar(200),
# newsImgUrl varchar(200),
# primary key(id)
# );
# regex 이용해서, re.sub(매개변수1,매개변수2,매개변수3)
# 매개변수1 : 특정 조건
# 매개변수2 : 대체할 문자
# 매개변수3 : regex를 적용할 문장.

# %%
import time
import bs4
import urllib.request
import pymysql
import re
def clean_text(inputString):
    text_rmv = re.sub(
        '[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
    return text_rmv

# 전역변수, 기사에서 가지고 올 정보만 선택한 변수.
title, price, cardimgUrl, productlink = "", "", "", ""
def insertData(title, price, cardimgUrl, productlink):
    # con : 파이썬 <-> mysql 연결하기 위한 인스턴스, 도구
    # cur : 디비의 정보를 조작하기위한 도구.
    con, cur = None, None
    data = ""
    data0, data1, data2, data3, data4 = "", "", "", "", ""
    sql = ""
    con = pymysql.connect(host='127.0.0.1', user='webuser2',
                          password='webuser2', database='pydb', charset='utf8')
    cur = con.cursor()
    
    data1 = title
    data2 = price
    data3 = cardimgUrl
    data4 = productlink
   
    
    try:
        # print(null)
        # print("데이터 실행전 확인")
        # print(data1)
        # print(data2)
        # print(data3)
        # print(data4)
        # print(data5)
        # print(data6)
        query = "INSERT INTO newsTable2 (title, price, cardimgUrl, productlink) VALUES (%s, %s, %s, %s)"
        values = (data1, data2, data3, data4)
        print("순서2 : sql 실행전 ")
        # print(f"sql : {sql}")

        cur.execute(query, values)

    except:
        print('================================')
        print("순서3 : 예외 발생")
        print('================================')
        
    else:
        print('================================')
        print("순서3: 성공")
        print('================================')
        
    con.commit()
    con.close()
##
page = 1
count = 1
nateUrl = "https://www.gmarket.co.kr/n/list?category=200001105&gate_id=3A2E9AF9-CE52-48F6-B415-B662749F2C73"

while True:
  if (count != 201):
    try:
        # newsUrl = nateUrl + str(page)
        newsUrl = nateUrl
        # page += 1
        htmlObject = urllib.request.urlopen(newsUrl)
        webPage = htmlObject.read()
        bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
        tag_list = bsObject.findAll('div', {'class': 'box__item-container'})
        print('G마켓 상품')
        for tag in tag_list:
          if (count != 201):
            # strong -> h2 변경 231210 (확인 날짜)
            title = tag.find('span', {'class': 'text__item'}).text
            title = clean_text(title)
            price = tag.find('div', {'class': 'box__price-seller'}).text
            price = clean_text(price)
            imgLink = tag.find('div', {'class': 'box__image'})
              # 이미지 없는 경우 처리 부분. 파이썬 null 대신  None
            if imgLink != None:
                cardimgUrl = imgLink.find('img')['src']
                cardimgUrl = 'https:' + cardimgUrl
            else:
                imgLinkUrl = '이미지가 존재 하지 않음'
            productlink = tag.find('a', {'class': 'link__item'})['href']
            productlink = productlink
            
          
           
                # continue
            print("순서1: 데이터 추가 전")
            print("title: %s" % (title))
            print("price: %s" % (price))
            print("productlink: %s" % (productlink))
            print("cardimgUrl: %s" % (cardimgUrl))
            print('================================')
            print('================================')
            insertData(title, price, cardimgUrl,productlink)
            count += 1
            # print('(' , page, ')', subject)
            # print('\t https:'+link, press, pDate, pTime)
            # print('\t imgLink : '+ imgLinkUrl)
          else:
            break
        
        time.sleep(1)
        print(f"count : {count}, page : {page}")
        # print(f"완료!")
        
    except:
        break
  else:
     print(f"완료!")
     break
    # else:
    #     break
    # 특정 시간마다 동작 여부
    # time.sleep(60)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\it\AppData\Local\Temp\ipykernel_11664\2328984734.py:8: SyntaxWarning: invalid escape sequence '\?'
#   '[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString)
# G마켓 상품
# 순서1: 데이터 추가 전
# title: 충전형 무선 버티컬 마우스 RX 800V
# price: 할인률12%판매가26 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2697860121&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2697860121/still/280?ver=1721268854
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 신티크프로16 DTH 167 터치 액정타블렛  구매이벤트 필름부착옵션
# price: 할인률3%판매가1 869 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2600006764&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2600006764/still/280?ver=1720337020
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 리브 블루투스키보드 간편키보드 태블릿키보드
# price: 판매가19 800원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2677638168&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2677638168/still/280?ver=1669358125
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 타블렛 펜심 ACK 20001 인튜어스4 5 프로 범용 스탠다드 펜심
# price: 판매가6 600원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1473053046&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1473053046/still/280?ver=1680496049
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 블루투스 키보드 휴대용키보드 초슬림 무선
# price: 판매가28 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1653597140&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1653597140/still/280?ver=1565166265
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 CTL 472 원바이와콤 소형 타블렛 당일발송
# price: 판매가53 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1592748197&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1592748197/still/280?ver=1599725152
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: KM730R 무선 키보드 마우스 세트 저소음 키스킨 포함
# price: 판매가17 800원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2774400134&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2774400134/still/280?ver=1720963530
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 앱코K660 게이밍 카일광축 기계식키보드 화이트리니어
# price: 할인률4%판매가59 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1868630117&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1868630117/still/280?ver=1664431302
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트22 2세대  액정타블렛 구매이벤트 전용스탠드 포함
# price: 할인률10%판매가538 200원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633406538&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633406538/still/280?ver=1699599749
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트12 2세대  액정타블렛  블랙 구매이벤트 한국정품 드로잉 태블릿
# price: 할인률10%판매가269 100원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633440421&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633440421/still/280?ver=1710302555
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트 프로16 액정타블렛 2세대 신제품 구매이벤트 2 5K 지원
# price: 판매가699 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635105765&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635105765/still/280?ver=1714636162
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트16 2세대  액정타블렛 블랙 구매이벤트 한국정품 드로잉 태블릿
# price: 할인률10%판매가445 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2712454500&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2712454500/still/280?ver=1712719271
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 무선 무소음 옵티컬 마우스 RX 550 블랙   2 4Ghz
# price: 할인률25%판매가14 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1564845533&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1564845533/still/280?ver=1719792798
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 신티크22 DTK 2260 스탠드포함  구매이벤트 필름부착옵션
# price: 할인률3%판매가1 339 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=604259377&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/604259377/still/280?ver=1721280279
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트24 프로 액정타블렛 구매이벤트   정품스탠드 포함
# price: 할인률10%판매가990 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635055696&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635055696/still/280?ver=1714010602
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트24 QHD 액정타블렛 구매이벤트   정품스탠드 포함
# price: 할인률10%판매가873 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633621111&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633621111/still/280?ver=1714010681
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트10 2세대  액정타블렛  BK 구매이벤트 한국정품 드로잉 태블릿
# price: 판매가250 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635230178&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635230178/still/280?ver=1685527331
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트16 2세대  액정타블렛  어린왕자 블랙에디션   구매이벤트 한국정품 드로잉 태블릿
# price: 할인률10%판매가445 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=3354471164&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/3354471164/still/280?ver=1703210483
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트13 2세대  액정타블렛  BK 구매이벤트 한국정품 드로잉 태블릿
# price: 판매가389 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635158671&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635158671/still/280?ver=1709193922
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스
500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1885168730
# cardimgUrl: https://gdimg.gmarket.co.kr/1885168730/still/280?ver=1600140621
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 항균 듀얼 블루투스 무선키보드마우스세트 MEDIC BS1
# price: 할인률3%판매가55 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2225861479
# cardimgUrl: https://gdimg.gmarket.co.kr/2225861479/still/280?ver=1631773064
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 스마일 MEDIC WM5 항균 무소음 무선 마우스
# price: 할인률3%판매가17 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2496242457
# cardimgUrl: https://gdimg.gmarket.co.kr/2496242457/still/280?ver=1657009040
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 스마일 SPA KKA1BUW 유선 화이트키보드 USB연결타입
# price: 할인률3%판매가17 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2096533326
# cardimgUrl: https://gdimg.gmarket.co.kr/2096533326/still/280?ver=1619164927
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: DeathStalker V2 Pro Linear Red KR 데스스토커 V2 Pro 무선 리니어레드 한글
# price: 할인률3%판매가319 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2536466739
# cardimgUrl: https://gdimg.gmarket.co.kr/2536466739/still/280?ver=1661999059
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# count : 106, page : 1
# G마켓 상품
# 순서1: 데이터 추가 전
# title: 충전형 무선 버티컬 마우스 RX 800V
# price: 할인률12%판매가26 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2697860121&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2697860121/still/280?ver=1721268854
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 신티크프로16 DTH 167 터치 액정타블렛  구매이벤트 필름부착옵션
# price: 할인률3%판매가1 869 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2600006764&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2600006764/still/280?ver=1720337020
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 리브 블루투스키보드 간편키보드 태블릿키보드
# price: 판매가19 800원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2677638168&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2677638168/still/280?ver=1669358125
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 타블렛 펜심 ACK 20001 인튜어스4 5 프로 범용 스탠다드 펜심
# price: 판매가6 600원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1473053046&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1473053046/still/280?ver=1680496049
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 블루투스 키보드 휴대용키보드 초슬림 무선
# price: 판매가28 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1653597140&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1653597140/still/280?ver=1565166265
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 CTL 472 원바이와콤 소형 타블렛 당일발송
# price: 판매가53 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1592748197&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1592748197/still/280?ver=1599725152
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: KM730R 무선 키보드 마우스 세트 저소음 키스킨 포함
# price: 판매가17 800원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2774400134&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2774400134/still/280?ver=1720963530
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 앱코K660 게이밍 카일광축 기계식키보드 화이트리니어
# price: 할인률4%판매가59 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1868630117&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1868630117/still/280?ver=1664431302
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트22 2세대  액정타블렛 구매이벤트 전용스탠드 포함
# price: 할인률10%판매가538 200원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633406538&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633406538/still/280?ver=1699599749
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트12 2세대  액정타블렛  블랙 구매이벤트 한국정품 드로잉 태블릿
# price: 할인률10%판매가269 100원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633440421&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633440421/still/280?ver=1710302555
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트 프로16 액정타블렛 2세대 신제품 구매이벤트 2 5K 지원
# price: 판매가699 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635105765&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635105765/still/280?ver=1714636162
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트16 2세대  액정타블렛 블랙 구매이벤트 한국정품 드로잉 태블릿
# price: 할인률10%판매가445 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2712454500&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2712454500/still/280?ver=1712719271
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 무선 무소음 옵티컬 마우스 RX 550 블랙   2 4Ghz
# price: 할인률25%판매가14 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1564845533&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/1564845533/still/280?ver=1719792798
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 와콤 신티크22 DTK 2260 스탠드포함  구매이벤트 필름부착옵션
# price: 할인률3%판매가1 339 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=604259377&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/604259377/still/280?ver=1721280279
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트24 프로 액정타블렛 구매이벤트   정품스탠드 포함
# price: 할인률10%판매가990 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2635055696&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2635055696/still/280?ver=1714010602
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스트24 QHD 액정타블렛 구매이벤트   정품스탠드 포함
# price: 할인률10%판매가873 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2633621111&buyboxtype=ad
# cardimgUrl: https://gdimg.gmarket.co.kr/2633621111/still/280?ver=1714010681
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 엑스피펜 XP PEN 아티스
900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1645446689
# cardimgUrl: https://gdimg.gmarket.co.kr/1645446689/still/280?ver=1693197633
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 로지텍 MK275  정품  무선 키보드 마우스 세트 로지텍 로지텍 MK275  정품  무선 키보드 마우스 세트 로지텍
# price: 할인률3%판매가28 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2344393218
# cardimgUrl: https://gdimg.gmarket.co.kr/2344393218/still/280?ver=1721377299
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 스틸시리즈 Prime 유선 게이밍 마우스
# price: 할인률55%판매가39 660원
# productlink: http://item.gmarket.co.kr/Item?goodscode=3274623854
# cardimgUrl: https://gdimg.gmarket.co.kr/3274623854/still/280?ver=1716252815
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: SRP 9610B 미니 무선키보드마우스세트 블랙
# price: 할인률3%판매가29 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2259367567
# cardimgUrl: https://gdimg.gmarket.co.kr/2259367567/still/280?ver=1635223816
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 그린레이저포인터 무선프리젠터 스마트포인터 SP 800 고선명 그린레이저 프리젠터
# price: 할인률2%판매가57 500원
# productlink: http://item.gmarket.co.kr/Item?goodscode=971817795
# cardimgUrl: https:https://pics.gmarket.co.kr/mobile/single/kr/common/tag__adult.png?ver=1720415786
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: PPT하이라이트1 디지털 포인터 프리젠터 레이저포인터 TV모니터용 무선프리젠터
# price: 할인률1%판매가65 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2497355468
# cardimgUrl: https:https://pics.gmarket.co.kr/mobile/single/kr/common/tag__adult.png?ver=1720748299
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 컴퓨터 USB 유선 게이밍 마우스 로지텍 M90 블랙
# price: 판매가11 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1181212571
# cardimgUrl: https://gdimg.gmarket.co.kr/1181212571/still/280?ver=1690512779
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 로지텍 G304 무선 게이밍 마우스 병행 밀봉박스새상품
# price: 할인률1%판매가43 290원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1468424485
# cardimgUrl: https://gdimg.gmarket.co.kr/1468424485/still/280?ver=1717554264
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: Huntsman V2 Linear KR 헌츠맨 V2 옵티컬 리니어 한글
# price: 할인률3%판매가219 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=2321146449
# cardimgUrl: https://gdimg.gmarket.co.kr/2321146449/still/280?ver=1698802173
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: MK295 블랙 SILENT 무소음 무선 콤보 2색상 국내정품 한영각인
# price: 할인률3%판매가39 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=3349940172
# cardimgUrl: https://gdimg.gmarket.co.kr/3349940172/still/280?ver=1721265002
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 미키마우스 멀티페어링 무선 블루투스 키보드  저소음 태블릿거치대 포토카드홀더
# price: 할인률3%판매가29 800원
# productlink: http://item.gmarket.co.kr/Item?goodscode=3850028700
# cardimgUrl: https://gdimg.gmarket.co.kr/3850028700/still/280?ver=1721008167
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 스마일 정품 SKP 900B 유선키보드마우스세트 USB타입
# price: 할인률3%판매가23 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1883963565
# cardimgUrl: https://gdimg.gmarket.co.kr/1883963565/still/280?ver=1600140726
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: DH  IPLEX VM712 휴 Ergo 손목보호 유선 버티컬마우스
# price: 판매가20 900원
# productlink: http://item.gmarket.co.kr/Item?goodscode=507216088
# cardimgUrl: https://gdimg.gmarket.co.kr/507216088/still/280?ver=1600226855
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# 순서1: 데이터 추가 전
# title: 로지텍 코리아 MK850 블루투스 멀티 무선 콤보 스마일캐쉬 5% 추가 적립
# price: 할인률4%판매가129 000원
# productlink: http://item.gmarket.co.kr/Item?goodscode=1102109911
# cardimgUrl: https://gdimg.gmarket.co.kr/1102109911/still/280?ver=1720578434
# ================================
# ================================
# 순서2 : sql 실행전
# ================================
# 순서3: 성공
# ================================
# count : 201, page : 1
# 완료!
